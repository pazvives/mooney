# %% [markdown]
# This notebook just shows five images for the two key datasets we use in this project:
# - BinarizedVOCDataset (generated from VOC)
# - HumanDataset (generated from images from real human experiment - includes manually handcrafted and validated Mooneys)

# %%
import torch
import torchvision

from utils.plotting import view_images
from datasets import HumanDataset, BinarizedVOCDataset
from torch.utils.data import DataLoader
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# # Visualizing BinaryVOC Dataset

# %%
binary_voc_train_ds = BinarizedVOCDataset(image_set = 'train', download = False)
print(len(binary_voc_train_ds))
# Out:
# 5717

# %%
for i in range(5):
    gray, binary  = binary_voc_train_ds[i]
    view_images([gray, binary])

# %% [markdown]
# # Visualizing Human Experiment Dataset

# %%
human_ds      = HumanDataset()
print(len(human_ds))
# Out:
# 219

# %%
for i in range(5):
    gray, mooney  = human_ds[i]
    view_images([gray, mooney])
